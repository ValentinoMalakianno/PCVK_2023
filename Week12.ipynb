# %% [markdown]
# <a href="https://colab.research.google.com/github/ValentinoMalakianno/PCVK_2023/blob/main/Week12.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ###**Valentino Malakianno**
# ###**3G**
# ###**2141720099**

# %% [markdown]
# **Jobsheet 12 – Feature Matching, Face Detection, Face Tracking**

# %% [markdown]
# **Import Library**

# %%
import cv2 as cv
import cv2
from google.colab.patches import cv2_imshow
import numpy as np
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from PIL import Image

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# **1. Percobaan - Face Detection**

# %%
cascade_wajah = cv.CascadeClassifier('/content/drive/MyDrive/Face Detection/haarcascade_frontalface_alt.xml')

jokowi = cv.imread('/content/drive/MyDrive/Face Detection/jokowi.jpg',0)
roi_wajah = cascade_wajah.detectMultiScale(jokowi)
for(x,y,w,h) in roi_wajah:
  cv.rectangle(jokowi,(x,y),(x+w,y+h),(255,255,255),3)
plt.figure(figsize = (5,5))
plt.imshow(jokowi, cmap='gray')

# %% [markdown]
# **Membuat Fungsi untuk Memudahkan Konversi Warna Citra**

# %%
def bgr_to_rgb(images):
  return cv2.cvtColor(images, cv2.COLOR_BGR2RGB)

def gray_to_rgb(images):
  return cv2.cvtColor(images, cv2.COLOR_GRAY2RGB)

def bgr_to_gray(images):
  return cv2.cvtColor(images, cv2.COLOR_BGR2GRAY)

# %% [markdown]
# **2. Face Detection untuk Beberapa Citra**

# %%
# Mendefinisikan Cascade Classifier
cascade_wajah = cv2.CascadeClassifier('/content/drive/MyDrive/Face Detection/haarcascade_frontalface_alt.xml')

# Jokowi

jokowi_bgr = cv2.imread('/content/drive/MyDrive/PCVK_2023/Images/facedet/jokowi.jpg')
jokowi = cv2.imread('/content/drive/MyDrive/PCVK_2023/Images/facedet/jokowi.jpg')

# Mendeteksi wajah
roi_wajah = cascade_wajah.detectMultiScale(jokowi_bgr)

# Menggambar kotak hijau di sekitar wajah pada gambar BGR
for (x, y, w, h) in roi_wajah:
    cv2.rectangle(jokowi_bgr, (x, y), (x+w, y+h), (0, 255, 0), 3)

# Mengonversi gambar BGR ke RGB menggunakan fungsi bgr_to_rgb
jokowi_rgb = bgr_to_rgb(jokowi_bgr)

# Menampilkan gambar dengan kotak hijau di sekitar wajah
plt.figure(figsize=(8, 8))
plt.subplot(121), plt.imshow(bgr_to_rgb(jokowi))
plt.axis('off')
plt.subplot(122), plt.imshow(jokowi_rgb)
plt.axis('off')
plt.show()


# RA. Kartini

kartini_bgr = cv2.imread('/content/drive/MyDrive/PCVK_2023/Images/facedet/kartini.jpg')
kartini = cv2.imread('/content/drive/MyDrive/PCVK_2023/Images/facedet/kartini.jpg')

# Mendeteksi wajah
roi_wajah = cascade_wajah.detectMultiScale(kartini_bgr)

# Menggambar kotak hijau di sekitar wajah pada gambar BGR
for (x, y, w, h) in roi_wajah:
    cv2.rectangle(kartini_bgr, (x, y), (x+w, y+h), (0, 255, 0), 3)

# Mengonversi gambar BGR ke RGB menggunakan fungsi bgr_to_rgb
kartini_rgb = bgr_to_rgb(kartini_bgr)

# Menampilkan gambar dengan kotak hijau di sekitar wajah
plt.figure(figsize=(8, 8))
plt.subplot(121), plt.imshow(bgr_to_rgb(kartini))
plt.axis('off')
plt.subplot(122), plt.imshow(kartini_rgb)
plt.axis('off')
plt.show()

# Kucing

kucing_bgr = cv2.imread('/content/drive/MyDrive/PCVK_2023/Images/facedet/kucing.jpg',0)
kucing = cv2.imread('/content/drive/MyDrive/PCVK_2023/Images/facedet/kucing.jpg',0)

# Mendeteksi wajah
roi_wajah = cascade_wajah.detectMultiScale(kucing_bgr)

# Menggambar kotak hijau di sekitar wajah pada gambar BGR
for (x, y, w, h) in roi_wajah:
    cv2.rectangle(kucing_bgr, (x, y), (x+w, y+h), (0, 255, 0), 3)

# Mengonversi gambar BGR ke RGB menggunakan fungsi bgr_to_rgb
kucing_rgb = bgr_to_rgb(kucing_bgr)

# Menampilkan gambar dengan kotak hijau di sekitar wajah
plt.figure(figsize=(8, 8))
plt.subplot(121), plt.imshow(kucing, cmap='gray')
plt.axis('off')
plt.subplot(122), plt.imshow(kucing_bgr, cmap='gray')
plt.axis('off')
plt.show()

# Perempuan bermasker

mask_gray = cv2.imread('/content/drive/MyDrive/PCVK_2023/Images/facedet/mask.png',0)

# Mendeteksi wajah
roi_wajah = cascade_wajah.detectMultiScale(mask_gray)

# Mengonversi gambar grayscale ke RGB untuk menyimpan warna hijau
mask_gray_rgb = gray_to_rgb(mask_gray)

# Menggambar kotak hijau di sekitar wajah pada gambar BGR
for (x, y, w, h) in roi_wajah:
    cv2.rectangle(mask_gray_rgb, (x, y), (x+w, y+h), (0, 255, 0), 3)

# Menampilkan gambar dengan kotak hijau di sekitar wajah
plt.figure(figsize=(8, 8))
plt.subplot(121), plt.imshow(mask_gray, cmap='gray')
plt.axis('off')
plt.subplot(122), plt.imshow(mask_gray_rgb)
plt.axis('off')
plt.show()

# Jordan

jordan_gray = cv2.imread('/content/drive/MyDrive/PCVK_2023/Images/facedet/mjordan.jpg',0)

# Mendeteksi wajah
roi_wajah = cascade_wajah.detectMultiScale(jordan_gray)

# Mengonversi gambar grayscale ke RGB untuk menyimpan warna hijau
jordan_gray_rgb = gray_to_rgb(jordan_gray)

# Menggambar kotak hijau di sekitar wajah pada gambar BGR
for (x, y, w, h) in roi_wajah:
    cv2.rectangle(jordan_gray_rgb, (x, y), (x+w, y+h), (0, 255, 0), 3)

# Menampilkan gambar dengan kotak hijau di sekitar wajah
plt.figure(figsize=(8, 8))
plt.subplot(121), plt.imshow(jordan_gray, cmap='gray')
plt.axis('off')
plt.subplot(122), plt.imshow(jordan_gray_rgb)
plt.axis('off')
plt.show()

# Solvayconf

solvay_gray = cv2.imread('/content/drive/MyDrive/PCVK_2023/Images/facedet/solvayconf.jpg', 0)

# Mendeteksi wajah
roi_wajah = cascade_wajah.detectMultiScale(solvay_gray)

# Mengonversi gambar grayscale ke RGB untuk menyimpan warna hijau
solvay_gray_rgb = gray_to_rgb(solvay_gray)

# Menggambar kotak hijau di sekitar wajah pada gambar grayscale
for (x, y, w, h) in roi_wajah:
    cv2.rectangle(solvay_gray_rgb, (x, y), (x+w, y+h), (0, 255, 0), 3)

# Menampilkan kedua gambar
plt.figure(figsize=(8, 8))

plt.subplot(121), plt.imshow(solvay_gray, cmap='gray')
plt.axis('off')

plt.subplot(122), plt.imshow(solvay_gray_rgb)
plt.axis('off')

plt.show()

# %% [markdown]
# **3. Face Detection - Kucing**

# %% [markdown]
# Pada Soal No.2. wajah kucing tidak bisa dideteksi dengan baik. Lakukan deteksi wajah kucing hingga muncul rectangle pada bagian wajahnya. Petunjuk pada soal ini, perhatikan pretrained features yang telah disediakan OpenCV. Gunakan xml yang adajika memang telah disediakan. Jika belum ada, coba cari dengan searching melalui search engines.

# %%
cascade_wajah = cv.CascadeClassifier('/content/drive/MyDrive/PCVK_2023/Images/haarcascades/haarcascades/haarcascade_frontalcatface_extended.xml')
data = ['/content/drive/MyDrive/PCVK_2023/Images/facedet/kucing.jpg']

for i in data:
  image = cv.imread(i)
  image_ori = cv.imread(i)
  roi_wajah = cascade_wajah.detectMultiScale(image)
  for(x,y,w,h) in roi_wajah:
    cv.rectangle(image,(x,y),(x+w,y+h),(0,128,0),3)
  f, axarr = plt. subplots(1,2,figsize=(15,5))
  plt.subplot(121),plt.imshow(cv.cvtColor(image_ori, cv.COLOR_BGR2RGB))
  axarr[0].imshow(cv.cvtColor(image_ori, cv.COLOR_BGR2RGB))
  plt.subplot(122),plt.imshow(cv.cvtColor(image, cv.COLOR_BGR2RGB))
  axarr[1].imshow(cv.cvtColor(image, cv.COLOR_BGR2RGB))
  plt.show()

# %% [markdown]
# **4. Cobakan juga untuk eyes detection.**

# %%
cascade_wajah = cv.CascadeClassifier('/content/drive/MyDrive/PCVK_2023/Images/haarcascades/haarcascades/haarcascade_eye.xml')

jokowi = cv.imread('/content/drive/MyDrive/PCVK_2023/Images/facedet/jokowi.jpg')
jokowi_ori = cv.imread('/content/drive/MyDrive/PCVK_2023/Images/facedet/jokowi.jpg')
jokowi_gray = cv.cvtColor(jokowi, cv.COLOR_BGR2GRAY)
jokowi_ori_gray = cv.cvtColor(jokowi_ori, cv.COLOR_BGR2GRAY)

roi_wajah = cascade_wajah.detectMultiScale(jokowi_gray)
for (x,y,w,h) in roi_wajah:
  cv.rectangle(jokowi_gray,(x,y),(x+w,y+h),(255,255,255),3)

# Plot outputs
f, axarr = plt. subplots(1,2,figsize=(15,15))
plt.subplot(121),plt.imshow(jokowi_ori_gray, cmap='gray')
plt.subplot(122),plt.imshow(jokowi_gray, cmap='gray')
plt.show()

# %% [markdown]
# **5. Lakukan Face Tracking menggunakan Google Colab.** Petunjuk, Tutorial selengkapnya
# tentang akses kamera dan FaceDetection pada google colab dapat dilihat di link berikut: https://www.youtube.com/watch?v=YjWh7QvVH60

# %%
def js_to_image(js_reply):
  image_bytes = b64decode(js_reply.split(',')[1])
  jpg_as_np = np.frombuffer(image_bytes, dtype=np.uint8)
  img = cv.imdecode(jpg_as_np, flags=1)

  return img

def bbox_to_bytes(bbox_array):
  bbox_PIL = PIL.Image.fromarray(bbox_array, 'RGBA')
  iobuf = io.BytesIO()
  bbox_PIL.save(iobuf, format='png')
  bbox_bytes = 'data:image/png;base64,{}'.format((str(b64decode(iobuf.getvalue()), 'utf-8')))

  return bbox_to_bytes

# %%
cascade_face = cv.CascadeClassifier(cv.data.haarcascades + "haarcascade_frontalface_alt.xml")

# %%
import cv2 as cv
import numpy as np
from matplotlib import pyplot as plt
from IPython.display import display, Javascript, Image
from google.colab.output import eval_js
from base64 import b64decode, b64encode
def take_photo(filename='photo.jpg', quality=0.8):
  js = Javascript('''
    async function takePhoto(quality){
      const div = document.createElement('div');
      const capture = document.createElement('button');
      capture.textContent = 'Capture';
      div.appendChild(capture);

      const video = document.createElement('video');
      video.style.display = 'block';
      const stream = await navigator.mediaDevices.getUserMedia({video: true});

      document.body.appendChild(div);
      div.appendChild(video);
      video.srcObject = stream;
      await video.play();

      google.colab.output.setIframeHeight(document.documentElement.scrollHeight, true);

      await new Promise((resolve) => capture.onclick = resolve);

      const canvas = document.createElement('canvas');
      canvas.width = video.videoWidth;
      canvas.height = video.videoHeight;
      canvas.getContext('2d').drawImage(video, 0, 0);
      stream.getVideoTracks()[0].stop();
      div.remove();
      return canvas.toDataURL('image/jpeg', quality);
    }
    ''')
  display(js)

  data = eval_js('takePhoto({})'.format(quality))
  img = js_to_image(data)
  gray = cv.cvtColor(img, cv.COLOR_RGB2GRAY)
  print(gray.shape)
  faces = cascade_face.detectMultiScale(gray)
  for(x,y,w,h) in faces:
    img = cv.rectangle(img,(x,y),(x+w,y+h),(255, 0, 0),2)

  cv.imwrite(filename, img)

  return filename

# %%
try:
  filename = take_photo('photo.jpg')
  print('Saved to {}'.format(filename))

  display(Image(filename))
except Exception as err:
  print(str(err))
# Out:
# (480, 640)
# Saved to photo.jpg

# %% [markdown]
# **6. Lakukan Blurring pada bagian wajah yang terdeteksi.**
#
# Berikut contoh keluarannya.
# Petunjuk: anda dapat menggunakan cv.medianBlur untuk melakukan Blurring

# %%
import cv2
import matplotlib.pyplot as plt

# Fungsi untuk mendeteksi wajah menggunakan OpenCV Haarcascades
def detect_faces(image_path):
    # Baca gambar
    image = cv2.imread(image_path)
    # Konversi gambar ke grayscale
    gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)

    # Inisialisasi Haar Cascade untuk deteksi wajah
    face_cascade = cv2.CascadeClassifier(cv2.data.haarcascades + 'haarcascade_frontalface_default.xml')

    # Deteksi wajah pada gambar
    faces = face_cascade.detectMultiScale(gray, scaleFactor=1.3, minNeighbors=5, minSize=(30, 30))

    return faces, image

# Fungsi untuk melakukan blurring pada bagian wajah
def blur_faces(image, faces):
    for (x, y, w, h) in faces:
        # Ambil ROI (Region of Interest) pada wajah
        face_roi = image[y:y+h, x:x+w]

        # Lakukan blurring menggunakan cv2.medianBlur
        blurred_face = cv2.medianBlur(face_roi, 15)

        # Ganti bagian wajah pada gambar asli dengan wajah yang sudah di-blur
        image[y:y+h, x:x+w] = blurred_face

    return image

# Path gambar input
image_path = '/content/drive/MyDrive/PCVK_2023/Images/facedet/mjordan.jpg'

# Deteksi wajah
faces, original_image = detect_faces(image_path)

# Blurring wajah
blurred_image = blur_faces(original_image, faces)

# Tampilkan gambar asli dan hasil blurring
plt.figure(figsize=(10, 5))


plt.subplot(1, 2, 2)
plt.imshow(cv2.cvtColor(blurred_image, cv2.COLOR_BGR2RGB))
plt.title('Blurred Faces')
plt.axis('off')

plt.show()

# %%
mjordan = cv.imread('/content/drive/MyDrive/PCVK_2023/Images/facedet/mjordan.jpg',1)
mjordan = cv.cvtColor(mjordan,cv.COLOR_BGR2RGB)
copy_wajah = mjordan.copy()
smile = cv.imread('/content/drive/MyDrive/PCVK_2023/Images/facedet/smile.png',1)
smile = cv.cvtColor(smile,cv.COLOR_BGR2RGB)

roi_wajah = cascade_wajah.detectMultiScale(mjordan)

for(x,y,w,h) in roi_wajah:
  copy_wajah = copy_wajah[y:y+h,x:x+w]
  # blur_wajah = cv.medianBlur(copy_wajah,15)
  smile_copy = cv.resize(smile, (w, h))
  mjordan[y:y+h,x:x+w] = smile_copy
plt.figure(figsize = (10,10))
plt.imshow(mjordan, cmap='gray')

# %%
from matplotlib.colors import ColorConverter
cascade_mata = cv.CascadeClassifier('/content/drive/MyDrive/PCVK_2023/Images/haarcascades/haarcascades/haarcascade_eye.xml')
cascade_wajah = cv.CascadeClassifier('/content/drive/MyDrive/PCVK_2023/Images/haarcascades/haarcascades/haarcascade_frontalcatface.xml')
cascade_mata_kanan = cv.CascadeClassifier('/content/drive/MyDrive/PCVK_2023/Images/haarcascades/haarcascades/haarcascade_righteye_2splits.xml')
ppl=[]
ppl = plt.imread('/content/drive/MyDrive/PCVK_2023/Images/facedet/people.jpg',1)

roi_mata = cascade_mata.detectMultiScale(ppl)
roi_wajah = cascade_wajah.detectMultiScale(ppl)
roi_smile = cascade_mata_kanan.detectMultiScale(ppl)
for(x,y,w,h) in roi_mata:
  cv.rectangle(ppl,(x,y),(x+w,y+h),(255,255,255),1)
for(x,y,w,h) in roi_wajah:
  cv.rectangle(ppl,(x,y),(x+w,y+h),(0,0,0),1)
for(x,y,w,h) in roi_smile:
  cv.rectangle(ppl,(x,y),(x+w,y+h),(255,0,0),2)
plt.figure(figsize = (10,10))
plt.imshow(ppl)
